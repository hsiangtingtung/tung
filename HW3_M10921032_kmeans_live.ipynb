# %%
#匯入模組
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
import collections

from sklearn.preprocessing import LabelEncoder
from sklearn.cluster import KMeans
from sklearn import cluster, datasets, metrics
from sklearn.decomposition import PCA

# %%
#讀取資料
original_live_data = pd.read_csv('drive/My Drive/Yuntech109_1/DataMining/Homework03/Live.csv')

# %%
#檢視資料
original_live_data
# Out:
#                               status_id status_type  ... Column3  Column4
# 0      246675545449582_1649696485147474       video  ...     NaN      NaN
# 1      246675545449582_1649426988507757       photo  ...     NaN      NaN
# 2      246675545449582_1648730588577397       video  ...     NaN      NaN
# 3      246675545449582_1648576705259452       photo  ...     NaN      NaN
# 4      246675545449582_1645700502213739       photo  ...     NaN      NaN
# ...                                 ...         ...  ...     ...      ...
# 7045  1050855161656896_1061863470556065       photo  ...     NaN      NaN
# 7046  1050855161656896_1061334757275603       photo  ...     NaN      NaN
# 7047  1050855161656896_1060126464063099       photo  ...     NaN      NaN
# 7048  1050855161656896_1058663487542730       photo  ...     NaN      NaN
# 7049  1050855161656896_1050858841656528       photo  ...     NaN      NaN
#
# [7050 rows x 16 columns]

# %%
live_data = original_live_data

# %%
#把時間欄位轉為時間格式，在後面就可以直接取「月份、日期、小時」
live_data['status_published'] = pd.to_datetime(live_data['status_published'])

# %%
# 新增月份、日期、小時
# 因為前面已經把欄位轉為時間格式，
# 所以這邊就可以用.dt的方式去拿時間的元素
live_data['year'] = live_data['status_published'].dt.year
live_data['month'] = live_data['status_published'].dt.month
live_data['date'] = live_data['status_published'].dt.day
live_data['hour'] = live_data['status_published'].dt.hour

# %%
#列出所有欄位
live_data.columns
# Out:
# Index(['status_id', 'status_type', 'status_published', 'num_reactions',
#        'num_comments', 'num_shares', 'num_likes', 'num_loves', 'num_wows',
#        'num_hahas', 'num_sads', 'num_angrys', 'Column1', 'Column2', 'Column3',
#        'Column4', 'year', 'month', 'date', 'hour'],
#       dtype='object')

# %%
#刪除多餘欄位
live_data = live_data.drop(['status_id', 'Column1', 'Column2', 'Column3', 'Column4'], axis=1)

# %%
#檢視資料
live_data
# Out:
#      status_type    status_published  num_reactions  ...  month  date  hour
# 0          video 2018-04-22 06:00:00            529  ...      4    22     6
# 1          photo 2018-04-21 22:45:00            150  ...      4    21    22
# 2          video 2018-04-21 06:17:00            227  ...      4    21     6
# 3          photo 2018-04-21 02:29:00            111  ...      4    21     2
# 4          photo 2018-04-18 03:22:00            213  ...      4    18     3
# ...          ...                 ...            ...  ...    ...   ...   ...
# 7045       photo 2016-09-24 02:58:00             89  ...      9    24     2
# 7046       photo 2016-09-23 11:19:00             16  ...      9    23    11
# 7047       photo 2016-09-21 23:03:00              2  ...      9    21    23
# 7048       photo 2016-09-20 00:43:00            351  ...      9    20     0
# 7049       photo 2016-09-10 10:30:00             17  ...      9    10    10
#
# [7050 rows x 15 columns]

# %%
#設定label正規化
labelencoder = LabelEncoder()

# %%
#將不是數值型態的轉為Label
live_data['status_type'] = labelencoder.fit_transform(live_data['status_type'])

# %%
#檢視資料
live_data
# Out:
#       status_type    status_published  num_reactions  ...  month  date  hour
# 0               3 2018-04-22 06:00:00            529  ...      4    22     6
# 1               1 2018-04-21 22:45:00            150  ...      4    21    22
# 2               3 2018-04-21 06:17:00            227  ...      4    21     6
# 3               1 2018-04-21 02:29:00            111  ...      4    21     2
# 4               1 2018-04-18 03:22:00            213  ...      4    18     3
# ...           ...                 ...            ...  ...    ...   ...   ...
# 7045            1 2016-09-24 02:58:00             89  ...      9    24     2
# 7046            1 2016-09-23 11:19:00             16  ...      9    23    11
# 7047            1 2016-09-21 23:03:00              2  ...      9    21    23
# 7048            1 2016-09-20 00:43:00            351  ...      9    20     0
# 7049            1 2016-09-10 10:30:00             17  ...      9    10    10
#
# [7050 rows x 15 columns]

# %%
#列出所有欄位
live_data.columns
# Out:
# Index(['status_type', 'status_published', 'num_reactions', 'num_comments',
#        'num_shares', 'num_likes', 'num_loves', 'num_wows', 'num_hahas',
#        'num_sads', 'num_angrys', 'year', 'month', 'date', 'hour'],
#       dtype='object')

# %%
#將x放入要分群的資料
x = live_data.drop(['status_published', 'year', 'month', 'date', 'hour'], axis=1)
x
# Out:
#       status_type  num_reactions  num_comments  ...  num_hahas  num_sads  num_angrys
# 0               3            529           512  ...          1         1           0
# 1               1            150             0  ...          0         0           0
# 2               3            227           236  ...          1         0           0
# 3               1            111             0  ...          0         0           0
# 4               1            213             0  ...          0         0           0
# ...           ...            ...           ...  ...        ...       ...         ...
# 7045            1             89             0  ...          0         0           0
# 7046            1             16             0  ...          1         0           0
# 7047            1              2             0  ...          0         0           0
# 7048            1            351            12  ...          0         0           0
# 7049            1             17             0  ...          0         0           0
#
# [7050 rows x 10 columns]

# %%
#y為原始分群的結果
y = live_data['year']
y
# Out:
# 0       2018
# 1       2018
# 2       2018
# 3       2018
# 4       2018
#         ...
# 7045    2016
# 7046    2016
# 7047    2016
# 7048    2016
# 7049    2016
# Name: year, Length: 7050, dtype: int64

# %%
#K-means分群
#查看分幾群會得到最佳的purity
ks = range(2, 21)
for k in ks:
    KKSTticks=time.clock()
    kmeans_fit = cluster.KMeans(n_clusters = k).fit(x)
    cluster_labels = kmeans_fit.labels_
    #計算純度
    def purity(result,label):
        total_num = len(label)
        cluster_counter = collections.Counter(result)
        original_counter = collections.Counter(label)
        t=[]
        for k in cluster_counter:
            p_k = []
            for j in original_counter:
                 count = 0
                 for i in range(len(result)):
                     #求交集
                     if result[i] == k and label[i] == j:
                         count += 1
                 p_k.append(count)
            temp_t = max(p_k)
            t.append(temp_t)
        return sum(t)/total_num
    #計算每群的績效
    print('Kmeans績效：',k,'群,')
    KKEDticks=time.clock()
    print('Kmeans所花費時間：',KKEDticks-KKSTticks)
    print('Kmeans純度：',purity(cluster_labels,y))
# Out:
# Kmeans績效： 2 群, 0.8721887987065559
# Kmeans所花費時間： 1.4260629999999992
# Kmeans純度： 0.3649645390070922
# Kmeans績效： 3 群, 0.8121362145545791
# Kmeans所花費時間： 1.387366
# Kmeans純度： 0.3843971631205674
# Kmeans績效： 4 群, 0.8175569885388427
# Kmeans所花費時間： 1.6463499999999982
# Kmeans純度： 0.3853900709219858
# Kmeans績效： 5 群, 0.7851527120560737
# Kmeans所花費時間： 1.5812639999999973
# Kmeans純度： 0.39404255319148934
# Kmeans績效： 6 群, 0.7615238190978312
# Kmeans所花費時間： 1.6398589999999977
# Kmeans純度： 0.3853900709219858
# Kmeans績效： 7 群, 0.7610431462235427
# Kmeans所花費時間： 1.6862120000000047
# Kmeans純度： 0.384822695035461
# Kmeans績效： 8 群, 0.761366932397758
# Kmeans所花費時間： 1.7691609999999969
# Kmeans純度： 0.38765957446808513
# Kmeans績效： 9 群, 0.6574081788616235
# Kmeans所花費時間： 1.7567949999999968
# Kmeans純度： 0.3921985815602837
# Kmeans績效： 10 群, 0.6818950609494551
# Kmeans所花費時間： 1.8632889999999946
# Kmeans純度： 0.3941843971631206
# Kmeans績效： 11 群, 0.6836739833139458
# Kmeans所花費時間： 1.7727369999999993
# Kmeans純度： 0.3941843971631206
# Kmeans績效： 12 群, 0.6843340492019799
# Kmeans所花費時間： 1.8127429999999976
# Kmeans純度： 0.3941843971631206
# Kmeans績效： 13 群, 0.6951713007106638
# Kmeans所花費時間： 1.8747840000000053
# Kmeans純度： 0.3923404255319149
# Kmeans績效： 14 群, 0.6601909516612758
# Kmeans所花費時間： 1.8777290000000022
# Kmeans純度： 0.40070921985815605
# Kmeans績效： 15 群, 0.6567136095140269
# Kmeans所花費時間： 2.045994999999998
# Kmeans純度： 0.4002836879432624
# Kmeans績效： 16 群, 0.655012371395363
# Kmeans所花費時間： 1.9313649999999996
# Kmeans純度： 0.40070921985815605
# Kmeans績效： 17 群, 0.6597522641979682
# Kmeans所花費時間： 2.0638269999999963
# Kmeans純度： 0.4022695035460993
# Kmeans績效： 18 群, 0.6596159291601669
# Kmeans所花費時間： 1.9826970000000017
# Kmeans純度： 0.4026950354609929
# Kmeans績效： 19 群, 0.6349265952048143
# Kmeans所花費時間： 2.1676080000000013
# Kmeans純度： 0.40198581560283686
# Kmeans績效： 20 群, 0.6332802763907017
# Kmeans所花費時間： 2.169229999999999
# Kmeans純度： 0.4025531914893617
